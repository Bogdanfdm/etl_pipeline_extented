# %%
import pandas as pd
import os 
import pyarrow as pa
import pyarrow.parquet as pq
from sqlalchemy import create_engine, text
import duckdb as ddb
from pathlib import Path

# %%
path_csv = Path("/home/bodya/Desktop/projects/fraud-detection/data/data_for_insert/csv/team_history.csv")

ddb_con = ddb.connect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 path_csv = Path(__file__).resolve().parent.parent / 'data' / 'data_for_insert' / 'csv'
#       3 ddb_con = ddb.connect()
#
# NameError: name '__file__' is not defined

# %%
for csv in path_csv.glob("*.csv"):
    print(f"reading {csv}")
    df = ddb_con.execute(
        f"""
        DESCRIBE SELECT * FROM read_csv_auto('{csv}')
         """
    ).df()
    print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 for csv in path_csv.glob("*.csv"):
#       2     print(f"reading {csv}")
#       3     df = ddb_con.execute(
#       4         f"""
#       5         DESCRIBE SELECT * FROM read_csv_auto('{csv}')
#       6          """
#       7     ).df()
#
# NameError: name 'path_csv' is not defined
